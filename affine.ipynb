# %%
import numpy as np
import pandas as pd
import sklearn
import cv2
from scipy.ndimage.interpolation import map_coordinates
from scipy.ndimage.filters import gaussian_filter
import matplotlib.pyplot as plt
import sys
sys.path.append('..')

import torch
from torch import nn
from torch.autograd import Variable
from torchvision.datasets import mnist # 导入 pytorch 内置的 mnist 数据

# %%
# Elastic transform
def elastic_transformations(alpha, sigma, rng=np.random.RandomState(42), 
                            interpolation_order=1):
    """Returns a function to elastically transform multiple images."""
    # Good values for:
    #   alpha: 2000
    #   sigma: between 40 and 60
    def _elastic_transform_2D(images):
        """`images` is a numpy array of shape (K, M, N) of K images of size M*N."""
        # Take measurements
        image_shape = images[0].shape
        # Make random fields
        dx = rng.uniform(-1, 1, image_shape) * alpha
        dy = rng.uniform(-1, 1, image_shape) * alpha
        # Smooth dx and dy
        sdx = gaussian_filter(dx, sigma=sigma, mode='reflect')
        sdy = gaussian_filter(dy, sigma=sigma, mode='reflect')
        # Make meshgrid
        x, y = np.meshgrid(np.arange(image_shape[1]), np.arange(image_shape[0]))
        # Distort meshgrid indices
        distorted_indices = (y + sdy).reshape(-1, 1), \
                            (x + sdx).reshape(-1, 1)

        # Map cooordinates from image to distorted index set
        transformed_images = [map_coordinates(image, distorted_indices, mode='reflect',
                                              order=interpolation_order).reshape(image_shape)
                              for image in images]
        return transformed_images
    return _elastic_transform_2D

# %%
# 使用内置函数下载 mnist 数据集
train_set = mnist.MNIST('./data', train=True, download=True)
test_set = mnist.MNIST('./data', train=False, download=True)

# %%
def data_tf(x):
    x = np.array(x, dtype='float32') / 255
    x = (x - 0.5) / 0.5 # 标准化，这个技巧之后会讲到
    x = x.reshape(1,28,28)
    x = torch.from_numpy(x)
    
    return x

train_set = mnist.MNIST('./data', train=True, transform=data_tf, download=True) # 重新载入数据集，申明定义的数据变换
test_set = mnist.MNIST('./data', train=False, transform=data_tf, download=True)

a, a_label = train_set[0]
print(a.shape)
print(a_label)
# Out:
# torch.Size([1, 28, 28])
# 5

# %%
from torch.utils.data import DataLoader
# 使用 pytorch 自带的 DataLoader 定义一个数据迭代器
train_data = DataLoader(train_set, batch_size=64, shuffle=True)
test_data = DataLoader(test_set, batch_size=128, shuffle=False)
print(train_data.dataset)
print(test_data.dataset)
a, a_label = next(iter(train_data))
# 打印出一个批次的数据大小
print(a.shape)
print(a_label.shape)
# Out:
# Dataset MNIST
#     Number of datapoints: 60000
#     Root location: ./data
#     Split: Train
#     StandardTransform
# Transform: <function data_tf at 0x000000001A877158>
# Dataset MNIST
#     Number of datapoints: 10000
#     Root location: ./data
#     Split: Test
#     StandardTransform
# Transform: <function data_tf at 0x000000001A877158>
# torch.Size([64, 1, 28, 28])
# torch.Size([64])

# %%
import cupy
def Random_affine(image,alpha_affine,random_state=None):
    if random_state is None:
        random_state = np.random.RandomState(None)
    shape = image.shape
    shape_size = shape[:2]
    # Random affine
    center_square = np.float32(shape_size) // 2
    square_size = min(shape_size) // 3
    pts1 = np.float32([center_square + square_size, [center_square[0]+square_size, center_square[1]-square_size], center_square - square_size])
    pts2 = pts1 + random_state.uniform(-alpha_affine, alpha_affine, size=pts1.shape).astype(np.float32)
    M = cv2.getAffineTransform(pts1, pts2)
    #print(image.shape)
    #print(M)
    #print(shape_size[::-1])
    image = cupy.asnumpy(image)
    image = cv2.warpAffine(image,M,shape_size[::-1],borderValue=-1)
    
    return image

# %%
class SimpleConv(nn.Module):
    def __init__(self):
        super(SimpleConv,self).__init__()
        self.layer1=nn.Sequential(nn.Conv2d(1,5,kernel_size=5,stride=(2,2),padding=(1,1)),nn.BatchNorm2d(5),nn.Sigmoid())#5 13 13
        self.layer2=nn.Sequential(nn.Conv2d(5,50,kernel_size=5,stride=(2,2)),nn.BatchNorm2d(50),nn.Sigmoid()) #50 5 5
       
        self.fc=nn.Sequential(
            nn.Linear(5*5*50,100),
            nn.Sigmoid(),
            nn.Linear(100,10),
        )
        
    def forward(self,x):
        x =  self.layer1(x)
        x =  self.layer2(x)
        x =  x.view(x.size(0),-1)#展平
        x =  self.fc(x)
        return  x

# %%
print(torch.cuda.is_available())
if(torch.cuda.is_available()):
    net=SimpleConv().cuda()
    print("cuda")
else:
    net=SimpleConv()
net.train()
# Out:
# True
# cuda
# SimpleConv(
#   (layer1): Sequential(
#     (0): Conv2d(1, 5, kernel_size=(5, 5), stride=(2, 2), padding=(1, 1))
#     (1): BatchNorm2d(5, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): Sigmoid()
#   )
#   (layer2): Sequential(
#     (0): Conv2d(5, 50, kernel_size=(5, 5), stride=(2, 2))
#     (1): BatchNorm2d(50, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): Sigmoid()
#   )
#   (fc): Sequential(
#     (0): Linear(in_features=1250, out_features=100, bias=True)
#     (1): Sigmoid()
#     (2): Linear(in_features=100, out_features=10, bias=True)
#   )
# )

# %%
import torch.optim as optim
from torch.optim import lr_scheduler
# 定义 loss 函数
loss_func  = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(net.parameters(), 0.005) # 使用随机梯度下降，学习率 0.1
scheduler = lr_scheduler.StepLR(optimizer, step_size=100, gamma=0.3)

# %%
#将预训练模型载入
net.load_state_dict(torch.load('./affine.pth',map_location='cpu'))
# Out:
# <All keys matched successfully>

# %%
from datetime import datetime
def get_acc(output, label):
    total = output.shape[0]
    _, pred_label = output.max(1)
    num_correct = (pred_label == label).sum().item()
    return num_correct / total


def train(net, train_data, valid_data, num_epochs, optimizer, criterion,scheduler):
    if torch.cuda.is_available():
        net = net.cuda()
    prev_time = datetime.now()
    for epoch in range(num_epochs):
        scheduler.step()
        train_loss = 0
        train_acc = 0
        net = net.train()
        for im, label in train_data:  
          new_data=[]
          train_list=[]
          train_list.append(im)
          
          for i in range(im.shape[0]):
              a_data=np.reshape(im[i],(28,28))
              affine=Random_affine(a_data,4)
              affine=np.reshape(affine,(1,28,28))
              new_data.append(affine)

          '''   
          for i in range(im.shape[0]):             
              ela_temp=elastic_transformations(34,4)
              elastic=ela_temp(im[i])
              elastic=np.array(elastic, dtype='float32')
              new_data.append(elastic)
                
          '''      
          new_data=np.array(new_data)
          new_data=torch.from_numpy(new_data)
          train_list.append(new_data)
      
          for ims in train_list:
            if torch.cuda.is_available():
                ims = Variable(ims.cuda())  # (bs, 3, h, w)
                label = Variable(label.cuda())  # (bs, h, w)
            else:
                ims = Variable(ims)
                label = Variable(label)
            # forward
            #print(ims.shape)
            output = net(ims)
            loss = criterion(output, label)
            # backward
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            train_loss += loss.item()
            train_acc += get_acc(output, label)

        cur_time = datetime.now()
        h, remainder = divmod((cur_time - prev_time).seconds, 3600)
        m, s = divmod(remainder, 60)
        time_str = "Time %02d:%02d:%02d" % (h, m, s)
        if valid_data is not None:
            valid_loss = 0
            valid_acc = 0
            net = net.eval()
            for im, label in valid_data:
                if torch.cuda.is_available():
                    im = Variable(im.cuda(), volatile=True)
                    label = Variable(label.cuda(), volatile=True)
                else:
                    im = Variable(im, volatile=True)
                    label = Variable(label, volatile=True)
                output = net(im)
                loss = criterion(output, label)
                valid_loss += loss.item()
                valid_acc += get_acc(output, label)
            epoch_str = (
                "Epoch %d. Train Loss: %f, Train Acc: %f, Valid Loss: %f, Valid Acc: %f, "
                % (epoch, train_loss / len(train_data),
                   train_acc / len(train_data), valid_loss / len(valid_data),
                   valid_acc / len(valid_data)))
        else:
            epoch_str = ("Epoch %d. Train Loss: %f, Train Acc: %f, " %
                         (epoch, train_loss / len(train_data),
                          train_acc / len(train_data)))
        prev_time = cur_time
        print(epoch_str + time_str)

# %%
train(net, train_data, test_data, 200, optimizer, loss_func,scheduler=scheduler)
# Out:
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:70: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:71: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
# Epoch 0. Train Loss: 0.170041, Train Acc: 1.949710, Valid Loss: 0.033728, Valid Acc: 0.989419, Time 00:01:41
# Epoch 1. Train Loss: 0.166381, Train Acc: 1.951243, Valid Loss: 0.034963, Valid Acc: 0.989023, Time 00:01:46
# Epoch 2. Train Loss: 0.168882, Train Acc: 1.950160, Valid Loss: 0.033946, Valid Acc: 0.989320, Time 00:01:44
# Epoch 3. Train Loss: 0.166018, Train Acc: 1.950077, Valid Loss: 0.034736, Valid Acc: 0.989221, Time 00:01:46
# Epoch 4. Train Loss: 0.164459, Train Acc: 1.951443, Valid Loss: 0.034081, Valid Acc: 0.989419, Time 00:01:47
# Epoch 5. Train Loss: 0.166005, Train Acc: 1.950926, Valid Loss: 0.032989, Valid Acc: 0.990012, Time 00:01:47
# Epoch 6. Train Loss: 0.164468, Train Acc: 1.951026, Valid Loss: 0.033914, Valid Acc: 0.989122, Time 00:01:47
# Epoch 7. Train Loss: 0.166442, Train Acc: 1.951393, Valid Loss: 0.034024, Valid Acc: 0.989320, Time 00:01:43
# Epoch 8. Train Loss: 0.167015, Train Acc: 1.950376, Valid Loss: 0.033221, Valid Acc: 0.989517, Time 00:01:45
# Epoch 9. Train Loss: 0.166139, Train Acc: 1.952592, Valid Loss: 0.034233, Valid Acc: 0.989221, Time 00:01:43
# Epoch 10. Train Loss: 0.166191, Train Acc: 1.951176, Valid Loss: 0.033688, Valid Acc: 0.989122, Time 00:01:45
# Epoch 11. Train Loss: 0.164916, Train Acc: 1.951059, Valid Loss: 0.033355, Valid Acc: 0.989517, Time 00:01:45
# Epoch 12. Train Loss: 0.163882, Train Acc: 1.952109, Valid Loss: 0.033575, Valid Acc: 0.989419, Time 00:01:48
# Epoch 13. Train Loss: 0.165526, Train Acc: 1.951659, Valid Loss: 0.034311, Valid Acc: 0.989221, Time 00:01:46
# Epoch 14. Train Loss: 0.168036, Train Acc: 1.951159, Valid Loss: 0.034198, Valid Acc: 0.989221, Time 00:01:40
# Epoch 15. Train Loss: 0.165404, Train Acc: 1.951493, Valid Loss: 0.033947, Valid Acc: 0.989419, Time 00:01:36
# Epoch 16. Train Loss: 0.165763, Train Acc: 1.951493, Valid Loss: 0.033585, Valid Acc: 0.989517, Time 00:01:36
# Epoch 17. Train Loss: 0.163985, Train Acc: 1.952892, Valid Loss: 0.033687, Valid Acc: 0.989715, Time 00:01:36
# Epoch 18. Train Loss: 0.161599, Train Acc: 1.952559, Valid Loss: 0.034136, Valid Acc: 0.989517, Time 00:01:36
# Epoch 19. Train Loss: 0.164861, Train Acc: 1.951576, Valid Loss: 0.034195, Valid Acc: 0.988825, Time 00:01:36
# Epoch 20. Train Loss: 0.163774, Train Acc: 1.951709, Valid Loss: 0.033422, Valid Acc: 0.989419, Time 00:01:36
# Epoch 21. Train Loss: 0.169125, Train Acc: 1.950526, Valid Loss: 0.033727, Valid Acc: 0.989419, Time 00:01:36
# Epoch 22. Train Loss: 0.167503, Train Acc: 1.950860, Valid Loss: 0.034995, Valid Acc: 0.988924, Time 00:01:36
# Epoch 23. Train Loss: 0.165102, Train Acc: 1.951592, Valid Loss: 0.033000, Valid Acc: 0.990012, Time 00:01:35
# Epoch 24. Train Loss: 0.166621, Train Acc: 1.951226, Valid Loss: 0.034774, Valid Acc: 0.988825, Time 00:01:35
# Epoch 25. Train Loss: 0.162595, Train Acc: 1.952009, Valid Loss: 0.033515, Valid Acc: 0.989320, Time 00:01:36
# Epoch 26. Train Loss: 0.165646, Train Acc: 1.951859, Valid Loss: 0.033691, Valid Acc: 0.988924, Time 00:01:35
# Epoch 27. Train Loss: 0.163632, Train Acc: 1.952009, Valid Loss: 0.033671, Valid Acc: 0.989320, Time 00:01:35
# Epoch 28. Train Loss: 0.165955, Train Acc: 1.950027, Valid Loss: 0.033501, Valid Acc: 0.989320, Time 00:01:35
# Epoch 29. Train Loss: 0.164759, Train Acc: 1.951426, Valid Loss: 0.034172, Valid Acc: 0.988924, Time 00:01:47
# Epoch 30. Train Loss: 0.163652, Train Acc: 1.951992, Valid Loss: 0.033503, Valid Acc: 0.989517, Time 00:01:41
# Epoch 31. Train Loss: 0.161701, Train Acc: 1.952059, Valid Loss: 0.035024, Valid Acc: 0.988825, Time 00:01:41
# Epoch 32. Train Loss: 0.163845, Train Acc: 1.951909, Valid Loss: 0.034646, Valid Acc: 0.989221, Time 00:01:40
# Epoch 33. Train Loss: 0.164397, Train Acc: 1.952575, Valid Loss: 0.033951, Valid Acc: 0.989221, Time 00:01:39
# Epoch 34. Train Loss: 0.165666, Train Acc: 1.951009, Valid Loss: 0.034295, Valid Acc: 0.989122, Time 00:01:41
# Epoch 35. Train Loss: 0.162624, Train Acc: 1.952242, Valid Loss: 0.033237, Valid Acc: 0.989320, Time 00:01:49
# Epoch 36. Train Loss: 0.164616, Train Acc: 1.952809, Valid Loss: 0.034092, Valid Acc: 0.989122, Time 00:01:50
# Epoch 37. Train Loss: 0.162149, Train Acc: 1.952325, Valid Loss: 0.034567, Valid Acc: 0.989221, Time 00:01:49
# Epoch 38. Train Loss: 0.164217, Train Acc: 1.952559, Valid Loss: 0.034039, Valid Acc: 0.988924, Time 00:01:45
# Epoch 39. Train Loss: 0.165317, Train Acc: 1.951343, Valid Loss: 0.033451, Valid Acc: 0.989419, Time 00:01:52
# Epoch 40. Train Loss: 0.160344, Train Acc: 1.953242, Valid Loss: 0.032838, Valid Acc: 0.989715, Time 00:01:48
# Epoch 41. Train Loss: 0.165163, Train Acc: 1.950760, Valid Loss: 0.033892, Valid Acc: 0.989122, Time 00:01:44
# Epoch 42. Train Loss: 0.162960, Train Acc: 1.953008, Valid Loss: 0.033807, Valid Acc: 0.989221, Time 00:01:45
# Epoch 43. Train Loss: 0.164504, Train Acc: 1.951559, Valid Loss: 0.032710, Valid Acc: 0.989913, Time 00:01:44
# Epoch 44. Train Loss: 0.163796, Train Acc: 1.952659, Valid Loss: 0.033195, Valid Acc: 0.989320, Time 00:01:45
# Epoch 45. Train Loss: 0.160913, Train Acc: 1.952559, Valid Loss: 0.034068, Valid Acc: 0.988825, Time 00:01:46
# Epoch 46. Train Loss: 0.163021, Train Acc: 1.952042, Valid Loss: 0.032838, Valid Acc: 0.989715, Time 00:01:46
# Epoch 47. Train Loss: 0.164381, Train Acc: 1.951476, Valid Loss: 0.033929, Valid Acc: 0.989122, Time 00:01:44
# Epoch 48. Train Loss: 0.162855, Train Acc: 1.952092, Valid Loss: 0.033480, Valid Acc: 0.989221, Time 00:01:46
# Epoch 49. Train Loss: 0.162495, Train Acc: 1.951326, Valid Loss: 0.033095, Valid Acc: 0.989616, Time 00:01:49
# Epoch 50. Train Loss: 0.162503, Train Acc: 1.952659, Valid Loss: 0.033210, Valid Acc: 0.989419, Time 00:01:48
# Epoch 51. Train Loss: 0.163735, Train Acc: 1.951709, Valid Loss: 0.034230, Valid Acc: 0.989122, Time 00:01:45
# Epoch 52. Train Loss: 0.162447, Train Acc: 1.952692, Valid Loss: 0.033835, Valid Acc: 0.989122, Time 00:01:50
# Epoch 53. Train Loss: 0.161824, Train Acc: 1.952325, Valid Loss: 0.033425, Valid Acc: 0.989221, Time 00:01:50
# Epoch 54. Train Loss: 0.165494, Train Acc: 1.951476, Valid Loss: 0.033474, Valid Acc: 0.988924, Time 00:01:47
# Epoch 55. Train Loss: 0.163934, Train Acc: 1.951376, Valid Loss: 0.032861, Valid Acc: 0.989419, Time 00:01:49
# Epoch 56. Train Loss: 0.164290, Train Acc: 1.951443, Valid Loss: 0.034025, Valid Acc: 0.989221, Time 00:01:52
# Epoch 57. Train Loss: 0.161373, Train Acc: 1.952275, Valid Loss: 0.033350, Valid Acc: 0.989320, Time 00:01:58
# Epoch 58. Train Loss: 0.160928, Train Acc: 1.951859, Valid Loss: 0.033264, Valid Acc: 0.989320, Time 00:01:56
# Epoch 59. Train Loss: 0.165779, Train Acc: 1.950560, Valid Loss: 0.034247, Valid Acc: 0.988825, Time 00:01:48
# Epoch 60. Train Loss: 0.158601, Train Acc: 1.953558, Valid Loss: 0.033683, Valid Acc: 0.989122, Time 00:01:49
# Epoch 61. Train Loss: 0.164142, Train Acc: 1.951293, Valid Loss: 0.032920, Valid Acc: 0.990012, Time 00:01:49
# Epoch 62. Train Loss: 0.162404, Train Acc: 1.952076, Valid Loss: 0.033857, Valid Acc: 0.989023, Time 00:01:53
# Epoch 63. Train Loss: 0.162259, Train Acc: 1.951876, Valid Loss: 0.033734, Valid Acc: 0.989221, Time 00:01:48
# Epoch 64. Train Loss: 0.160851, Train Acc: 1.952825, Valid Loss: 0.033901, Valid Acc: 0.989122, Time 00:01:50
# Epoch 65. Train Loss: 0.161041, Train Acc: 1.952958, Valid Loss: 0.033054, Valid Acc: 0.989715, Time 00:01:47
# Epoch 66. Train Loss: 0.162978, Train Acc: 1.952325, Valid Loss: 0.033851, Valid Acc: 0.989221, Time 00:01:51
# Epoch 67. Train Loss: 0.163956, Train Acc: 1.952109, Valid Loss: 0.033119, Valid Acc: 0.989320, Time 00:01:52
# Epoch 68. Train Loss: 0.160487, Train Acc: 1.953425, Valid Loss: 0.033857, Valid Acc: 0.989221, Time 00:01:50
# Epoch 69. Train Loss: 0.163049, Train Acc: 1.951526, Valid Loss: 0.033475, Valid Acc: 0.988825, Time 00:01:52
# Epoch 70. Train Loss: 0.161670, Train Acc: 1.952775, Valid Loss: 0.032924, Valid Acc: 0.989122, Time 00:01:50
# Epoch 71. Train Loss: 0.164906, Train Acc: 1.952176, Valid Loss: 0.033442, Valid Acc: 0.989814, Time 00:01:48
# Epoch 72. Train Loss: 0.162599, Train Acc: 1.953225, Valid Loss: 0.032507, Valid Acc: 0.990210, Time 00:02:00
# Epoch 73. Train Loss: 0.163690, Train Acc: 1.950876, Valid Loss: 0.033237, Valid Acc: 0.989320, Time 00:02:04
# Epoch 74. Train Loss: 0.162185, Train Acc: 1.952908, Valid Loss: 0.032737, Valid Acc: 0.989419, Time 00:02:01
# Epoch 75. Train Loss: 0.163124, Train Acc: 1.952375, Valid Loss: 0.033394, Valid Acc: 0.989023, Time 00:02:06
# Epoch 76. Train Loss: 0.161758, Train Acc: 1.953125, Valid Loss: 0.033538, Valid Acc: 0.989320, Time 00:02:02
# Epoch 77. Train Loss: 0.162382, Train Acc: 1.951592, Valid Loss: 0.033136, Valid Acc: 0.989122, Time 00:02:02
# Epoch 78. Train Loss: 0.160826, Train Acc: 1.952109, Valid Loss: 0.032506, Valid Acc: 0.989715, Time 00:02:01
# Epoch 79. Train Loss: 0.160370, Train Acc: 1.952542, Valid Loss: 0.033407, Valid Acc: 0.989221, Time 00:02:02
# Epoch 80. Train Loss: 0.159154, Train Acc: 1.953258, Valid Loss: 0.032884, Valid Acc: 0.989517, Time 00:02:04
# Epoch 81. Train Loss: 0.160404, Train Acc: 1.953591, Valid Loss: 0.032953, Valid Acc: 0.989221, Time 00:02:07
# Epoch 82. Train Loss: 0.161381, Train Acc: 1.953058, Valid Loss: 0.032876, Valid Acc: 0.989616, Time 00:02:03
# Epoch 83. Train Loss: 0.161326, Train Acc: 1.952642, Valid Loss: 0.032831, Valid Acc: 0.990111, Time 00:02:03
# Epoch 84. Train Loss: 0.162156, Train Acc: 1.952675, Valid Loss: 0.034600, Valid Acc: 0.988331, Time 00:02:04
# Epoch 85. Train Loss: 0.160487, Train Acc: 1.952975, Valid Loss: 0.033655, Valid Acc: 0.988825, Time 00:02:02
# Epoch 86. Train Loss: 0.160696, Train Acc: 1.953475, Valid Loss: 0.033457, Valid Acc: 0.989221, Time 00:02:03
# Epoch 87. Train Loss: 0.160107, Train Acc: 1.952192, Valid Loss: 0.032772, Valid Acc: 0.989221, Time 00:02:03
# Epoch 88. Train Loss: 0.162223, Train Acc: 1.952076, Valid Loss: 0.033106, Valid Acc: 0.989221, Time 00:02:02
# Epoch 89. Train Loss: 0.159704, Train Acc: 1.953075, Valid Loss: 0.033423, Valid Acc: 0.989221, Time 00:02:06
# Epoch 90. Train Loss: 0.159978, Train Acc: 1.953791, Valid Loss: 0.033087, Valid Acc: 0.989419, Time 00:02:11
# Epoch 91. Train Loss: 0.160900, Train Acc: 1.952725, Valid Loss: 0.033107, Valid Acc: 0.989320, Time 00:02:05
# Epoch 92. Train Loss: 0.161708, Train Acc: 1.952126, Valid Loss: 0.032729, Valid Acc: 0.989320, Time 00:02:04
# Epoch 93. Train Loss: 0.161911, Train Acc: 1.952176, Valid Loss: 0.033102, Valid Acc: 0.989221, Time 00:02:09
# Epoch 94. Train Loss: 0.161459, Train Acc: 1.952625, Valid Loss: 0.032885, Valid Acc: 0.989023, Time 00:02:04
# Epoch 95. Train Loss: 0.157207, Train Acc: 1.954091, Valid Loss: 0.034076, Valid Acc: 0.988627, Time 00:02:03
# Epoch 96. Train Loss: 0.159841, Train Acc: 1.953308, Valid Loss: 0.033593, Valid Acc: 0.989122, Time 00:02:05
# Epoch 97. Train Loss: 0.159928, Train Acc: 1.953775, Valid Loss: 0.032704, Valid Acc: 0.989419, Time 00:02:07
# Epoch 98. Train Loss: 0.159834, Train Acc: 1.952809, Valid Loss: 0.033613, Valid Acc: 0.989221, Time 00:02:03
# Epoch 99. Train Loss: 0.160325, Train Acc: 1.953125, Valid Loss: 0.033631, Valid Acc: 0.988825, Time 00:02:03
# Epoch 100. Train Loss: 0.162603, Train Acc: 1.952409, Valid Loss: 0.032651, Valid Acc: 0.989320, Time 00:02:06
# Epoch 101. Train Loss: 0.160856, Train Acc: 1.953008, Valid Loss: 0.032562, Valid Acc: 0.989616, Time 00:01:53
# Epoch 102. Train Loss: 0.159485, Train Acc: 1.953608, Valid Loss: 0.033031, Valid Acc: 0.989320, Time 00:01:49
# Epoch 103. Train Loss: 0.159623, Train Acc: 1.953691, Valid Loss: 0.032981, Valid Acc: 0.989320, Time 00:01:50
# Epoch 104. Train Loss: 0.159758, Train Acc: 1.953408, Valid Loss: 0.032439, Valid Acc: 0.989913, Time 00:01:50
# Epoch 105. Train Loss: 0.157271, Train Acc: 1.953725, Valid Loss: 0.032790, Valid Acc: 0.989715, Time 00:01:50
# Epoch 106. Train Loss: 0.159786, Train Acc: 1.952759, Valid Loss: 0.033995, Valid Acc: 0.989221, Time 00:01:52
# Epoch 107. Train Loss: 0.157018, Train Acc: 1.953175, Valid Loss: 0.032497, Valid Acc: 0.989814, Time 00:01:51
# Epoch 108. Train Loss: 0.158621, Train Acc: 1.953142, Valid Loss: 0.033067, Valid Acc: 0.989320, Time 00:01:54
# Epoch 109. Train Loss: 0.160104, Train Acc: 1.952792, Valid Loss: 0.032567, Valid Acc: 0.989715, Time 00:01:53
# Epoch 110. Train Loss: 0.162587, Train Acc: 1.952742, Valid Loss: 0.033601, Valid Acc: 0.989122, Time 00:01:57
# Epoch 111. Train Loss: 0.158529, Train Acc: 1.954058, Valid Loss: 0.033042, Valid Acc: 0.989122, Time 00:01:53
# Epoch 112. Train Loss: 0.160251, Train Acc: 1.953075, Valid Loss: 0.032662, Valid Acc: 0.989517, Time 00:01:55
# Epoch 113. Train Loss: 0.160515, Train Acc: 1.953025, Valid Loss: 0.032511, Valid Acc: 0.989814, Time 00:01:48
# Epoch 114. Train Loss: 0.158779, Train Acc: 1.953925, Valid Loss: 0.033143, Valid Acc: 0.989221, Time 00:01:55
# Epoch 115. Train Loss: 0.161099, Train Acc: 1.952242, Valid Loss: 0.033356, Valid Acc: 0.989122, Time 00:01:44
# Epoch 116. Train Loss: 0.158946, Train Acc: 1.952775, Valid Loss: 0.032725, Valid Acc: 0.989320, Time 00:01:44
# Epoch 117. Train Loss: 0.159786, Train Acc: 1.953142, Valid Loss: 0.033336, Valid Acc: 0.989122, Time 00:01:55
# Epoch 118. Train Loss: 0.158691, Train Acc: 1.953092, Valid Loss: 0.032487, Valid Acc: 0.989814, Time 00:01:57
# Epoch 119. Train Loss: 0.158547, Train Acc: 1.953891, Valid Loss: 0.032773, Valid Acc: 0.989221, Time 00:01:49
# Epoch 120. Train Loss: 0.159454, Train Acc: 1.953558, Valid Loss: 0.033119, Valid Acc: 0.989517, Time 00:01:51
# Epoch 121. Train Loss: 0.158624, Train Acc: 1.952759, Valid Loss: 0.033005, Valid Acc: 0.989419, Time 00:01:53
# Epoch 122. Train Loss: 0.158193, Train Acc: 1.953591, Valid Loss: 0.033165, Valid Acc: 0.989320, Time 00:01:51
# Epoch 123. Train Loss: 0.159988, Train Acc: 1.952942, Valid Loss: 0.032895, Valid Acc: 0.989320, Time 00:01:47
# Epoch 124. Train Loss: 0.161298, Train Acc: 1.953108, Valid Loss: 0.032832, Valid Acc: 0.989320, Time 00:01:55
# Epoch 125. Train Loss: 0.160925, Train Acc: 1.952742, Valid Loss: 0.033398, Valid Acc: 0.989320, Time 00:01:56
# Epoch 126. Train Loss: 0.158242, Train Acc: 1.953625, Valid Loss: 0.033136, Valid Acc: 0.989517, Time 00:01:55
# Epoch 127. Train Loss: 0.157046, Train Acc: 1.954724, Valid Loss: 0.032368, Valid Acc: 0.989616, Time 00:01:51
# Epoch 128. Train Loss: 0.158148, Train Acc: 1.953025, Valid Loss: 0.033148, Valid Acc: 0.989023, Time 00:01:51
# Epoch 129. Train Loss: 0.158808, Train Acc: 1.953575, Valid Loss: 0.032739, Valid Acc: 0.989419, Time 00:01:49
# Epoch 130. Train Loss: 0.159197, Train Acc: 1.953458, Valid Loss: 0.032878, Valid Acc: 0.989419, Time 00:02:05
# Epoch 131. Train Loss: 0.157244, Train Acc: 1.954091, Valid Loss: 0.032238, Valid Acc: 0.989913, Time 00:01:55
# Epoch 132. Train Loss: 0.161783, Train Acc: 1.951942, Valid Loss: 0.032994, Valid Acc: 0.989320, Time 00:02:02
# Epoch 133. Train Loss: 0.158776, Train Acc: 1.953292, Valid Loss: 0.033107, Valid Acc: 0.989023, Time 00:01:58
# Epoch 134. Train Loss: 0.159663, Train Acc: 1.953208, Valid Loss: 0.032400, Valid Acc: 0.989616, Time 00:01:50
# Epoch 135. Train Loss: 0.160846, Train Acc: 1.952475, Valid Loss: 0.032630, Valid Acc: 0.989616, Time 00:01:47
# Epoch 136. Train Loss: 0.161547, Train Acc: 1.952325, Valid Loss: 0.032425, Valid Acc: 0.989616, Time 00:01:48
# Epoch 137. Train Loss: 0.158824, Train Acc: 1.952975, Valid Loss: 0.032982, Valid Acc: 0.989221, Time 00:01:46
# Epoch 138. Train Loss: 0.158518, Train Acc: 1.953591, Valid Loss: 0.032567, Valid Acc: 0.989419, Time 00:01:46
# Epoch 139. Train Loss: 0.159190, Train Acc: 1.953625, Valid Loss: 0.032833, Valid Acc: 0.989616, Time 00:01:46
# Epoch 140. Train Loss: 0.160262, Train Acc: 1.953491, Valid Loss: 0.032494, Valid Acc: 0.989913, Time 00:01:53
# Epoch 141. Train Loss: 0.157986, Train Acc: 1.954091, Valid Loss: 0.032933, Valid Acc: 0.989814, Time 00:01:49
# Epoch 142. Train Loss: 0.158509, Train Acc: 1.953875, Valid Loss: 0.032945, Valid Acc: 0.989023, Time 00:02:01
# Epoch 143. Train Loss: 0.158634, Train Acc: 1.954041, Valid Loss: 0.032597, Valid Acc: 0.989320, Time 00:02:01
# Epoch 144. Train Loss: 0.159077, Train Acc: 1.953058, Valid Loss: 0.032603, Valid Acc: 0.989419, Time 00:01:47
# Epoch 145. Train Loss: 0.159908, Train Acc: 1.953741, Valid Loss: 0.033122, Valid Acc: 0.988924, Time 00:01:47
# Epoch 146. Train Loss: 0.158630, Train Acc: 1.954324, Valid Loss: 0.032818, Valid Acc: 0.989221, Time 00:01:48
# Epoch 147. Train Loss: 0.159493, Train Acc: 1.953075, Valid Loss: 0.032706, Valid Acc: 0.989419, Time 00:01:51
# Epoch 148. Train Loss: 0.158216, Train Acc: 1.954174, Valid Loss: 0.032927, Valid Acc: 0.989320, Time 00:01:54
# Epoch 149. Train Loss: 0.159923, Train Acc: 1.953392, Valid Loss: 0.032097, Valid Acc: 0.989616, Time 00:01:55
# Epoch 150. Train Loss: 0.158761, Train Acc: 1.953441, Valid Loss: 0.032055, Valid Acc: 0.990210, Time 00:02:02
# Epoch 151. Train Loss: 0.158368, Train Acc: 1.952126, Valid Loss: 0.032613, Valid Acc: 0.989419, Time 00:01:49
# Epoch 152. Train Loss: 0.159990, Train Acc: 1.953125, Valid Loss: 0.032953, Valid Acc: 0.989122, Time 00:01:52
# Epoch 153. Train Loss: 0.160940, Train Acc: 1.951642, Valid Loss: 0.032160, Valid Acc: 0.990111, Time 00:01:51
# Epoch 154. Train Loss: 0.157723, Train Acc: 1.953242, Valid Loss: 0.032343, Valid Acc: 0.989616, Time 00:02:22
# Epoch 155. Train Loss: 0.158130, Train Acc: 1.954108, Valid Loss: 0.032863, Valid Acc: 0.989419, Time 00:01:59
# Epoch 156. Train Loss: 0.157215, Train Acc: 1.953675, Valid Loss: 0.032787, Valid Acc: 0.989221, Time 00:02:05
# Epoch 157. Train Loss: 0.158432, Train Acc: 1.954174, Valid Loss: 0.033425, Valid Acc: 0.989221, Time 00:02:18
# Epoch 158. Train Loss: 0.159242, Train Acc: 1.952392, Valid Loss: 0.032555, Valid Acc: 0.989419, Time 00:02:28
# Epoch 159. Train Loss: 0.158691, Train Acc: 1.952908, Valid Loss: 0.032621, Valid Acc: 0.989517, Time 00:02:37
# Epoch 160. Train Loss: 0.159887, Train Acc: 1.953225, Valid Loss: 0.032501, Valid Acc: 0.989517, Time 00:02:38
# Epoch 161. Train Loss: 0.157634, Train Acc: 1.954025, Valid Loss: 0.032903, Valid Acc: 0.989715, Time 01:36:15
# Epoch 162. Train Loss: 0.160193, Train Acc: 1.953108, Valid Loss: 0.032626, Valid Acc: 0.989419, Time 00:01:49
# Epoch 163. Train Loss: 0.159851, Train Acc: 1.953275, Valid Loss: 0.032403, Valid Acc: 0.990111, Time 00:01:48
# Epoch 164. Train Loss: 0.157074, Train Acc: 1.954508, Valid Loss: 0.032046, Valid Acc: 0.989913, Time 00:01:48
# Epoch 165. Train Loss: 0.158400, Train Acc: 1.952908, Valid Loss: 0.033264, Valid Acc: 0.989221, Time 00:01:49
# Epoch 166. Train Loss: 0.158350, Train Acc: 1.953475, Valid Loss: 0.032922, Valid Acc: 0.989419, Time 00:01:49
# Epoch 167. Train Loss: 0.160004, Train Acc: 1.954191, Valid Loss: 0.032205, Valid Acc: 0.989517, Time 00:01:49
# Epoch 168. Train Loss: 0.156952, Train Acc: 1.953725, Valid Loss: 0.032704, Valid Acc: 0.989616, Time 00:01:48
# Epoch 169. Train Loss: 0.156152, Train Acc: 1.953575, Valid Loss: 0.032364, Valid Acc: 0.989616, Time 00:01:48
# Epoch 170. Train Loss: 0.160826, Train Acc: 1.952725, Valid Loss: 0.032692, Valid Acc: 0.989517, Time 00:01:49
# Epoch 171. Train Loss: 0.157905, Train Acc: 1.952875, Valid Loss: 0.032598, Valid Acc: 0.989616, Time 00:01:49
# Epoch 172. Train Loss: 0.157775, Train Acc: 1.953058, Valid Loss: 0.032460, Valid Acc: 0.989616, Time 00:01:49
# Epoch 173. Train Loss: 0.159433, Train Acc: 1.953075, Valid Loss: 0.032366, Valid Acc: 0.989419, Time 00:01:48
# Epoch 174. Train Loss: 0.160138, Train Acc: 1.953125, Valid Loss: 0.032497, Valid Acc: 0.989715, Time 00:01:48
# Epoch 175. Train Loss: 0.159218, Train Acc: 1.954008, Valid Loss: 0.033437, Valid Acc: 0.989320, Time 00:01:49
# Epoch 176. Train Loss: 0.157750, Train Acc: 1.953741, Valid Loss: 0.032748, Valid Acc: 0.989616, Time 00:01:48
# Epoch 177. Train Loss: 0.158050, Train Acc: 1.953941, Valid Loss: 0.032599, Valid Acc: 0.989320, Time 00:01:49
# Epoch 178. Train Loss: 0.158771, Train Acc: 1.953258, Valid Loss: 0.032981, Valid Acc: 0.989320, Time 00:01:48
# Epoch 179. Train Loss: 0.157720, Train Acc: 1.953092, Valid Loss: 0.032747, Valid Acc: 0.989419, Time 00:01:48
# Epoch 180. Train Loss: 0.157911, Train Acc: 1.953641, Valid Loss: 0.032454, Valid Acc: 0.989616, Time 00:01:48
# Epoch 181. Train Loss: 0.157582, Train Acc: 1.954724, Valid Loss: 0.032953, Valid Acc: 0.989221, Time 00:01:49
# Epoch 182. Train Loss: 0.158516, Train Acc: 1.953858, Valid Loss: 0.032886, Valid Acc: 0.989122, Time 00:01:48
# Epoch 183. Train Loss: 0.157032, Train Acc: 1.953158, Valid Loss: 0.032881, Valid Acc: 0.989122, Time 00:01:49
# Epoch 184. Train Loss: 0.159003, Train Acc: 1.953342, Valid Loss: 0.032389, Valid Acc: 0.989814, Time 00:01:48
# Epoch 185. Train Loss: 0.158966, Train Acc: 1.953575, Valid Loss: 0.032670, Valid Acc: 0.989517, Time 00:01:48
# Epoch 186. Train Loss: 0.161304, Train Acc: 1.952858, Valid Loss: 0.032451, Valid Acc: 0.989913, Time 00:01:49
# Epoch 187. Train Loss: 0.160436, Train Acc: 1.952842, Valid Loss: 0.032417, Valid Acc: 0.989616, Time 00:01:48
# Epoch 188. Train Loss: 0.157754, Train Acc: 1.953641, Valid Loss: 0.032683, Valid Acc: 0.989221, Time 00:01:44
# Epoch 189. Train Loss: 0.159175, Train Acc: 1.953725, Valid Loss: 0.032288, Valid Acc: 0.989616, Time 00:01:37
# Epoch 190. Train Loss: 0.159508, Train Acc: 1.953425, Valid Loss: 0.033868, Valid Acc: 0.989023, Time 00:01:37
# Epoch 191. Train Loss: 0.159201, Train Acc: 1.953292, Valid Loss: 0.032757, Valid Acc: 0.989616, Time 00:01:38
# Epoch 192. Train Loss: 0.161523, Train Acc: 1.952958, Valid Loss: 0.032836, Valid Acc: 0.989517, Time 00:01:38
# Epoch 193. Train Loss: 0.158765, Train Acc: 1.953808, Valid Loss: 0.032591, Valid Acc: 0.989814, Time 00:01:37
# Epoch 194. Train Loss: 0.159146, Train Acc: 1.952592, Valid Loss: 0.033085, Valid Acc: 0.989517, Time 00:01:37
# Epoch 195. Train Loss: 0.160469, Train Acc: 1.952609, Valid Loss: 0.032668, Valid Acc: 0.989616, Time 00:01:37
# Epoch 196. Train Loss: 0.157695, Train Acc: 1.953608, Valid Loss: 0.032645, Valid Acc: 0.989419, Time 00:01:37
# Epoch 197. Train Loss: 0.157460, Train Acc: 1.955407, Valid Loss: 0.032373, Valid Acc: 0.989616, Time 00:01:39
# Epoch 198. Train Loss: 0.159131, Train Acc: 1.953975, Valid Loss: 0.032583, Valid Acc: 0.989517, Time 00:01:38
# Epoch 199. Train Loss: 0.158311, Train Acc: 1.953192, Valid Loss: 0.032491, Valid Acc: 0.989715, Time 00:01:37

# %%
#保存模型
model_path='./affine.pth'
torch.save(net.state_dict(),model_path)
